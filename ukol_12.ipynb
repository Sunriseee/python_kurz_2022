# %%
import pandas
import matplotlib.pyplot as plt

import requests

r = requests.get(
    "https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/platy_2021_02.csv")
open("platy_2021_02.csv", "wb").write(r.content)

platy = pandas.read_csv("platy_2021_02.csv")
platy
# Out:
#     cislo_zamestnance     plat
# 0                   3  54900.0
# 1                   6  54800.0
# 2                   7  36400.0
# 3                   8  47900.0
# 4                  16  34200.0
# 5                  18  35400.0
# 6                  21  54200.0
# 7                  22  34400.0
# 8                  23  39000.0
# 9                  24  44200.0
# 10                 26  59600.0
# 11                 27  45100.0
# 12                 28  38100.0
# 13                 29  48900.0
# 14                 30  33500.0
# 15                 32  53000.0
# 16                 33  38400.0
# 17                 34  36800.0
# 18                 38  32600.0
# 19                 40  32800.0
# 20                 41  49300.0
# 21                 44  52000.0
# 22                 47  40700.0
# 23                 49  58400.0
# 24                 51  37100.0
# 25                 56  39300.0
# 26                 57  36800.0
# 27                 63  31400.0
# 28                 64  36900.0
# ...

# %%
platy = platy.set_index("cislo_zamestnance")
platy.sort_values(by="plat") #tady se dívám jaké platy zaměstnanci mají, abych si okem stanovila intervaly pro histogram
# Out:
#                       plat
# cislo_zamestnance
# 63                 31400.0
# 95                 31600.0
# 38                 32600.0
# 69                 32600.0
# 40                 32800.0
# 30                 33500.0
# 16                 34200.0
# 22                 34400.0
# 18                 35400.0
# 7                  36400.0
# 34                 36800.0
# 57                 36800.0
# 64                 36900.0
# 51                 37100.0
# 28                 38100.0
# 33                 38400.0
# 84                 38600.0
# 23                 39000.0
# 56                 39300.0
# 47                 40700.0
# 90                 41100.0
# 85                 44200.0
# 24                 44200.0
# 27                 45100.0
# 83                 46500.0
# 8                  47900.0
# 92                 48100.0
# 29                 48900.0
# 74                 49300.0
# 41                 49300.0
# 87                 49900.0
# 96                 50200.0
# ...

# %%
platy_bez_cisla_zam = platy["plat"] # číslo zaměstnance v histogramu nemá smysl, proto vybírám jen sloupec s platem

# %%
#platy_bez_cisla_zam.hist(bins=[
 #   30000, 35000, 40000, 45000, 50000, 55000, 60000])
# více se mi líbí tato varianta, než ta výše zakomentovaná, ta je moc "messy"
platy_bez_cisla_zam.hist(bins=6)
# Out:
# <AxesSubplot: >

# %%
import requests

r = requests.get(
    "https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/temperature.csv")
open("temperature.csv", "wb").write(r.content)
teplota = pandas.read_csv("temperature.csv")
teplota
# Out:
#              Region  Country      City  Day  AvgTemperature
# 0            Africa  Algeria   Algiers    1            62.0
# 1            Africa  Algeria   Algiers    2            62.2
# 2            Africa  Algeria   Algiers    3            65.7
# 3            Africa  Algeria   Algiers    4            69.8
# 4            Africa  Algeria   Algiers    5            63.8
# ...             ...      ...       ...  ...             ...
# 8785  North America       US  Cheyenne   26            51.7
# 8786  North America       US  Cheyenne   27            55.5
# 8787  North America       US  Cheyenne   28            38.5
# 8788  North America       US  Cheyenne   29            36.8
# 8789  North America       US  Cheyenne   30            36.9
#
# [8790 rows x 5 columns]

# %%
teplota = teplota.set_index(["City", "Day"])
teplota
# Out:
#                      Region  Country  AvgTemperature
# City     Day
# Algiers  1           Africa  Algeria            62.0
#          2           Africa  Algeria            62.2
#          3           Africa  Algeria            65.7
#          4           Africa  Algeria            69.8
#          5           Africa  Algeria            63.8
# ...                     ...      ...             ...
# Cheyenne 26   North America       US            51.7
#          27   North America       US            55.5
#          28   North America       US            38.5
#          29   North America       US            36.8
#          30   North America       US            36.9
#
# [8790 rows x 3 columns]

# %%
hel = teplota.loc[["Helsinki"]] #výběr jen konkrétních měst
miam = teplota.loc[["Miami Beach"]]
tok = teplota.loc[["Tokyo"]]
vse = [tok,hel,miam]

# %%
teplota = pandas.DataFrame(columns=["Helsinki", "Miami Beach"])
teplota["Helsinki"] = hel
teplota["Miami Beach"] = miam
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [117], line 2
#       1 teplota = pandas.DataFrame(columns=["Helsinki", "Miami Beach"])
# ----> 2 teplota["Helsinki"] = hel
#       3 teplota["Miami Beach"] = miam
#
# File c:\Users\h.ruzickova\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3967, in DataFrame.__setitem__(self, key, value)
#    3965     self._setitem_array(key, value)
#    3966 elif isinstance(value, DataFrame):
# -> 3967     self._set_item_frame_value(key, value)
#    3968 elif (
#    3969     is_list_like(value)
#    3970     and not self.columns.is_unique
#    3971     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3972 ):
#    3973     # Column to set is duplicated
#    3974     self._setitem_array([key], value)
#
# ...

# %%
prum_tepl.plot(
    kind='box',
    # whiskers: the vertical lines extending to the most extreme, non-outlier data points.
    whis=[0, 100]
)

plt.show()

# %%
teplota = pd.DataFrame(np.random.randn(20, 3),
                       columns=['Helsinki', 'Miami Beach', 'Tokyo'])
boxplot = df.boxplot(column=['Helsinki', 'Miami Beach', 'Tokyo'])

# %%
hel = teplota.loc[["Helsinki"]]  # výběr jen konkrétních měst
miam = teplota.loc[["Miami Beach"]]
tok = teplota.loc[["Tokyo"]]
vse = [tok, hel, miam]

vse = [tok, hel, miam]

fig, ax = plt.subplots()
ax.boxplot(vse)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [81], line 1
# ----> 1 hel = teplota.loc[["Helsinki"]]  # výběr jen konkrétních měst
#       2 miam = teplota.loc[["Miami Beach"]]
#       3 tok = teplota.loc[["Tokyo"]]
#
# File c:\Users\h.ruzickova\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\h.ruzickova\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# ...
